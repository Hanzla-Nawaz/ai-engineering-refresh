# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
fashion_mnist = keras.datasets.fashion_mnist

# %%
fashion_mnist
# Out:
# <module 'keras.datasets.fashion_mnist' from 'c:\\Users\\hanzl\\anaconda3\\Lib\\site-packages\\keras\\datasets\\fashion_mnist\\__init__.py'>

# %%
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 1s 20us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 225s 9us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 2us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 14s 3us/step

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
y_train.shape
# Out:
# (60000,)

# %%
X_test.shape
# Out:
# (10000, 28, 28)

# %%
y_test.shape
# Out:
# (10000,)

# %%
X_train.dtype
# Out:
# dtype('uint8')

# %%
X_valid, X_train = X_train[:5000] / 255., X_train[5000:] / 255.

# %%
y_valid, y_train = y_train[:5000], y_train[5000:]

# %%
X_test = X_test / 255.

# %%
plt.imshow(X_train[0], cmap="binary")
plt.show()

# %%
print(y_train[0])
# Out:
# 4

# %%
X_train.shape
# Out:
# (55000, 28, 28)

# %%
class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
               "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# %%
class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
               "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]
class_names[y_train[0]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 class_names[y_train[0]]
#
# IndexError: list index out of range

# %%
n_rows = 4
n_cols = 10
plt.figure(figsize=(n_rows * 1.2, n_cols * 1.2))
for row in range(n_rows):
    for col in range(n_cols):
        index = row * n_cols + col
        plt.subplot(n_rows, n_cols, index + 1)
        plt.imshow(X_train[index], cmap="binary", vmin=0, vmax=1)
        plt.axis("off")
        plt.title(class_names[y_train[index]], fontsize=12)
    plt.subplots_adjust(wspace=0.5, hspace=0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[39], line 10
#       8         plt.imshow(X_train[index], cmap="binary", vmin=0, vmax=1)
#       9         plt.axis("off")
# ---> 10         plt.title(class_names[y_train[index]], fontsize=12)
#      11     plt.subplots_adjust(wspace=0.5, hspace=0.5)
#      12 plt.show()
#
# IndexError: list index out of range
