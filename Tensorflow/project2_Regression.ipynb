# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import warnings
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 4
#       2 from tensorflow import keras
#       3 import numpy as np
# ----> 4 import matplotlib.pylot as plt
#       5 import pandas as pd
#       6 import warnings
#
# ModuleNotFoundError: No module named 'matplotlib.pylot'

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Load the Boston Housing dataset
housing_data = fetch_california_housing()
X_train, X_test, y_train, y_test = train_test_split(housing_data.data,housing_data.target, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, random_state=42)

# %%
X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((11610, 8), (11610,), (3870, 8), (3870,), (5160, 8), (5160,))

# %%
len(X_train), len(y_train), len(X_val), len(y_val), len(X_test), len(y_test)
# Out:
# (11610, 11610, 3870, 3870, 5160, 5160)

# %%
print(X_train)
# Out:
# [[   3.5214       15.            3.04994451 ...    1.60599334
#     37.63       -122.43      ]
#  [   5.3275        5.            6.49005964 ...    3.44333996
#     33.69       -117.39      ]
#  [   3.1          29.            7.54237288 ...    2.25084746
#     38.44       -122.98      ]
#  ...
#  [   1.5561       35.            4.13993174 ...    3.27645051
#     34.11       -117.29      ]
#  [   2.1055       52.            5.17849462 ...    2.92688172
#     36.76       -119.79      ]
#  [   5.6022       31.            6.21971253 ...    2.53798768
#     38.04       -122.2       ]]

# %%
df_train = pd.DataFrame(X_train, columns=housing_data.feature_names)
print(df_train.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df_train = pd.DataFrame(X_train, columns=housing_data.feature_names)
#       2 print(df_train.head())
#
# NameError: name 'pd' is not defined
